# %%
with open("liste.txt") as file:
    data = list(map(int, file.readlines()))

# %%
data
# Out:
# [127,
#  147,
#  148,
#  147,
#  146,
#  153,
#  154,
#  167,
#  184,
#  181,
#  194,
#  183,
#  188,
#  195,
#  193,
#  207,
#  208,
#  220,
#  222,
#  234,
#  226,
#  247,
#  248,
#  253,
#  257,
#  250,
#  251,
#  285,
#  293,
#  294,
#  314,
#  311,
#  305,
#  312,
#  318,
#  321,
#  322,
#  344,
#  353,
#  354,
#  383,
#  391,
#  393,
#  394,
#  369,
#  373,
#  377,
#  378,
#  385,
#  388,
#  400,
#  402,
#  414,
#  422,
#  435,
#  414,
#  422,
#  436,
#  446,
#  455,
#  463,
#  478,
#  483,
#  482,
#  499,
#  495,
#  501,
#  506,
#  507,
#  509,
#  529,
#  522,
#  526,
#  527,
#  530,
#  529,
#  535,
#  536,
#  520,
#  525,
#  516,
#  518,
#  524,
#  525,
#  519,
#  520,
#  525,
#  531,
#  539,
#  551,
#  555,
#  579,
#  583,
#  594,
#  593,
#  594,
#  611,
#  610,
#  613,
#  616,
#  630,
#  637,
#  645,
#  641,
#  644,
#  646,
#  659,
#  671,
#  672,
#  676,
#  678,
#  682,
#  686,
#  688,
#  694,
#  720,
#  725,
#  735,
#  741,
#  742,
#  748,
#  745,
#  747,
#  752,
#  775,
# ...

# %%
a = 0

for i in range(len(data)):
    if i < (len(data) - 1):
        if data[i + 1] > data[i]:
            a += 1
    else:
        break
print(a)
# Out:
# 1602

# %%
a
# Out:
# 1602
